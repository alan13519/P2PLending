# %%
import pandas as pd
import glob
import warnings

# %%
warnings.filterwarnings("ignore")
list_dfs = [pd.read_csv(f) for f in glob.glob("data-all/*.csv")]

# %%
df_merged = pd.concat(list_dfs, axis=0)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2507557 entries, 0 to 131142
# Columns: 144 entries, id to settlement_term
# dtypes: float64(106), object(38)
# memory usage: 2.7+ GB

# %%
df_merged.describe(include='all')
# Out:
#                                                      id  member_id  \
# count                                                37        0.0
# unique                                               37        NaN
# top     Total amount funded in policy code 2: 520780182        NaN
# freq                                                  1        NaN
# mean                                                NaN        NaN
# std                                                 NaN        NaN
# min                                                 NaN        NaN
# 25%                                                 NaN        NaN
# 50%                                                 NaN        NaN
# 75%                                                 NaN        NaN
# max                                                 NaN        NaN
#
#            loan_amnt   funded_amnt  funded_amnt_inv        term int_rate  \
# count   2.507482e+06  2.507482e+06     2.507482e+06     2507482  2507482
# ...

# %%
df_merged = df_merged[df_merged['id'].isna()]

# %%
df_merged.to_csv("data/merged_df.csv")

# %% [markdown]
# This looks ugly but we can clean this

# %%
df = pd.read_csv("data/merged_df.csv")
len(df)
# Out:
# 2507520
